# %% [markdown]
# <a href="https://colab.research.google.com/github/EspecializacionIA1/Fundamentos_programacion_IA/blob/main/Divide_y_vencer%C3%A1s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Link del taller divide y vencerás

https://campusvirtuallms.javeriana.edu.co/shared/programas-virtuales/eia/semestre_1/fundamentos_programacion_ia/brightspace/assets/pdf/M02/MOD_02.DOCUMENTO_TALLER_INTEGRAR_FUNCIONES.pdf

Lista aleatoria, lista manual  -- Juan Ayala
MostrarLista - -- Julian
ManMax- clonar lista -- Leidy
sumarlistas --sergio
valor en lista -- Juanpa
MostrarMenu -- Juan Ayala

"""

# %%
# %%writefile funciones.py

from typing import List, Tuple
import random

def randomList(elementCount: int) -> List[int]:
    randomLt = [random.randint(0,10) for _ in range(elementCount)]
    return randomLt


def manualList(elementCount:int =10) -> List[int]:
    lt = []
    for i in range(elementCount):
      val = int(input(f"ingrese el valor {i + 1}: "))
      lt.append(val)
    return lt


def displayList(integerList: List[int]) -> None:
    pass


def minMax(integerList: List[int]) -> Tuple[int, int]:
    pass


def cloneList(originalList: List[int]) -> List[int]:
    pass


def sumLists(listA: List[int], listB: List[int]) -> List[int]:
    pass


def valueInList(integerList: List[int], targetValue: int) -> bool:
    pass
# Out:
# Overwriting funciones.py

# %%
# %%writefile menu.py

from funciones import randomList, manualList

# Menu section
def showMenu() -> int:
  print("//////// Menú Grupo 10 😎 //////////")
  print("1. Mostrar los valores de: listaUno y listaDos")
  print("2. Calcular el valor máximo y mínimo de la listaUno")
  print("3. Clonación de la listaUno")
  print("4. Sumar las listas: listaClonada y listaDos")
  print("5. Buscar algún valor dentro de lista suma")
  print("6. Salir")
  opt = int(input("Seleccione una de las opciones dadas:"))
  return opt

# bucle que se repite hasta que el usuari seleccione la opción 6.
while True:
  opt = showMenu()

  if opt == 1:
    print("Resultado de la lista uno: ", randomList(10))
    print("Resultado de la lista dos: ", manualList())
  elif opt == 6:
    print("Hasta luego!")
    break
  else:
    print("La opción ingresada no es válida")
# Out:
# Overwriting menu.py

# %%
# %run menu.py
# Out:
# //////// Menú Grupo 10 😎 //////////
# 1. Mostrar los valores de: listaUno y listaDos
# 2. Calcular el valor máximo y mínimo de la listaUno
# 3. Clonación de la listaUno
# 4. Sumar las listas: listaClonada y listaDos
# 5. Buscar algún valor dentro de lista suma
# 6. Salir
